# %% [markdown]
# # 🚗 Car Damage Assessment AI — YOLOv8 Training
#
# **Phase 2: Training a real CV model on the CarDD dataset**
#
# This notebook:
# 1. Installs YOLOv8 (ultralytics)
# 2. Downloads the CarDD dataset from Roboflow (YOLO format)
# 3. Trains YOLOv8n on 6 damage classes
# 4. Validates and shows metrics (mAP, precision, recall)
# 5. Tests on sample images
# 6. Exports `best.pt` for download
#
# **6 damage classes:** dent, scratch, crack, glass_shatter, broken_lamp, flat_tire
#
# ---
#
# ⚡ **Before running:** Go to `Runtime → Change runtime type → T4 GPU`

# %% [markdown]
# ## Step 0 — Verify GPU

# %%
# Verify GPU is available
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader

import torch
print(f"\nPyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ No GPU detected! Go to Runtime → Change runtime type → T4 GPU")
# Out:
# Tesla T4, 15360 MiB
#
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## Step 1 — Install dependencies

# %%
# Install ultralytics (YOLOv8) and roboflow
# !pip install -q ultralytics roboflow

from ultralytics import YOLO
import os
print("✅ Ultralytics installed successfully")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 87.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 135.0 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Ultralytics installed successfully

# %% [markdown]
# ## Step 2 — Download CarDD dataset from Roboflow
#
# The CarDD dataset contains ~4,000 car damage images with 9,000+ annotations across 6 damage categories.
#
# We use the Roboflow-hosted version which is already in YOLOv8 format.

# %%
from roboflow import Roboflow

# Download CarDD dataset in YOLOv8 format
# This is the public CarDD dataset hosted on Roboflow Universe
rf = Roboflow(api_key="h4f3OUamybWdCNxuLm1z")  # Free tier works fine
project = rf.workspace("cardd-diezp").project("detection-m16cd")
version = project.version(1)
dataset = version.download("yolov8")

print(f"\n✅ Dataset downloaded to: {dataset.location}")
print(f"\nDataset structure:")
# !ls {dataset.location}
print(f"\nTrain images:")
# !ls {dataset.location}/train/images | head -10
# !echo "... Total: $(ls {dataset.location}/train/images | wc -l) images"
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Detection-1 to yolov8:: 100%|██████████| 356436/356436 [00:22<00:00, 15737.18it/s]
# Extracting Dataset Version Zip to Detection-1 in yolov8:: 100%|██████████| 20012/20012 [00:02<00:00, 7005.74it/s]
# ✅ Dataset downloaded to: /content/Detection-1
#
# Dataset structure:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
#
# Train images:
# 000002_jpg.rf.2103f4011c08a4d1e76da350aac3eb7e.jpg
# 000002_jpg.rf.3473ee6a65c82dd1697794ee06a49ea5.jpg
# 000003_jpg.rf.1a9bf9b937ebaa788ce90712eb63b5e7.jpg
# 000003_jpg.rf.454899ad2ed9b6cd51c6f54485d50d0e.jpg
# 000005_jpg.rf.dabbbfb28697f1a78ae2877121122795.jpg
# 000006_jpg.rf.46291f0a57b8e68874c7c9f261374341.jpg
# 000006_jpg.rf.d3fe823551af3bca362036b55f9f03c1.jpg
# 000007_jpg.rf.8beac730196765ba96f7ff3315444281.jpg
# 000009_jpg.rf.337b5bb5460138696e7e35be257c5f73.jpg
# 000010_jpg.rf.45df4c93f31db46ec8786aa376ebd568.jpg
# ... Total: 7000 images

# %% [markdown]
# ### ⚠️ Getting a Roboflow API key (free)
#
# 1. Go to [roboflow.com](https://roboflow.com) → Sign up (free)
# 2. Go to Settings → API Key
# 3. Copy the key and paste above
#
# **Alternative: if you already have CarDD downloaded locally**, upload the zip to Colab and adjust the path in the training cell.

# %% [markdown]
# ## Step 3 — Inspect dataset

# %%
import yaml
from pathlib import Path

# Read and display data.yaml
data_yaml_path = f"{dataset.location}/data.yaml"
with open(data_yaml_path, 'r') as f:
    data_config = yaml.safe_load(f)

print("📋 Dataset configuration:")
print(f"   Classes: {data_config.get('names', 'N/A')}")
print(f"   Number of classes: {data_config.get('nc', 'N/A')}")
print(f"   Train path: {data_config.get('train', 'N/A')}")
print(f"   Val path: {data_config.get('val', 'N/A')}")
print(f"   Test path: {data_config.get('test', 'N/A')}")

# Count images
for split in ['train', 'valid', 'test']:
    img_dir = Path(dataset.location) / split / 'images'
    if img_dir.exists():
        count = len(list(img_dir.glob('*')))
        print(f"   {split}: {count} images")
# Out:
# 📋 Dataset configuration:
#    Classes: ['crack', 'crash', 'dent', 'dislocated part', 'glass shatter', 'lamp broken', 'no part', 'rub', 'scratch', 'tire flat']
#    Number of classes: 10
#    Train path: ../train/images
#    Val path: ../valid/images
#    Test path: ../test/images
#    train: 7000 images
#    valid: 2000 images
#    test: 1000 images

# %%
# Visualize a few training images with annotations
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

train_imgs = sorted((Path(dataset.location) / 'train' / 'images').glob('*'))[:6]
class_names = data_config.get('names', {})
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8', '#F7DC6F']

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('CarDD Training Samples', fontsize=16, fontweight='bold')

for idx, (ax, img_path) in enumerate(zip(axes.flat, train_imgs)):
    img = Image.open(img_path)
    ax.imshow(img)

    # Load corresponding label
    label_path = str(img_path).replace('/images/', '/labels/').rsplit('.', 1)[0] + '.txt'
    if os.path.exists(label_path):
        with open(label_path) as f:
            for line in f:
                parts = line.strip().split()
                cls_id = int(parts[0])
                x_center, y_center, w, h = map(float, parts[1:5])

                # Convert YOLO format to pixel coordinates
                img_w, img_h = img.size
                x1 = (x_center - w/2) * img_w
                y1 = (y_center - h/2) * img_h
                box_w = w * img_w
                box_h = h * img_h

                color = colors[cls_id % len(colors)]
                rect = patches.Rectangle((x1, y1), box_w, box_h,
                    linewidth=2, edgecolor=color, facecolor='none')
                ax.add_patch(rect)

                cls_name = class_names[cls_id] if cls_id < len(class_names) else f'class_{cls_id}'
                ax.text(x1, y1 - 5, cls_name, color=color,
                    fontsize=9, fontweight='bold',
                    bbox=dict(boxstyle='round,pad=0.2', facecolor='black', alpha=0.7))

    ax.set_title(img_path.name, fontsize=9)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4 — Train YOLOv8
#
# Training config:
# - **Model:** YOLOv8n (nano — fast, lightweight, good for demos and edge deployment)
# - **Epochs:** 50 (good balance of quality and training time)
# - **Image size:** 640px
# - **Batch size:** 16 (fits T4 GPU memory)
#
# Expected training time: **15–25 minutes** on T4 GPU.

# %%
# Train YOLOv8 on CarDD dataset
model = YOLO('yolov8n.pt')  # Start from pretrained COCO weights

results = model.train(
    data=data_yaml_path,
    epochs=50,
    imgsz=640,
    batch=16,
    name='cardd_damage',
    project='runs/detect',
    patience=10,        # Early stopping if no improvement for 10 epochs
    save=True,
    save_period=10,     # Save checkpoint every 10 epochs
    plots=True,         # Generate training plots
    verbose=True,
)

print("\n✅ Training complete!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 336.9MB/s 0.0s
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Detection-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=cardd_damage, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/runs/detect/cardd_damage, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 150.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 259.2MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1241.3±492.1 MB/s, size: 34.8 KB)
# train: Scanning /content/Detection-1/train/labels... 7000 images, 235 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7000/7000 1.6Kit/s 4.4s
# train: New cache created: /content/Detection-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 575.1±282.1 MB/s, size: 36.7 KB)
# val: Scanning /content/Detection-1/valid/labels... 2000 images, 79 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2000/2000 434.1it/s 4.6s
# val: New cache created: /content/Detection-1/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/runs/detect/cardd_damage/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/cardd_damage
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.04G      1.591      3.417      1.728         42        640: 100% ━━━━━━━━━━━━ 438/438 2.9it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.6it/s 17.4s
#                    all       2000       4430      0.471        0.2      0.218      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.57G      1.612      2.868      1.712         42        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.9s
#                    all       2000       4430      0.464      0.235      0.215      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.57G      1.611      2.682      1.707         25        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430        0.4      0.214      0.199      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.57G       1.59      2.578       1.69         30        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.8s
#                    all       2000       4430      0.387      0.309      0.261      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.57G      1.574      2.498      1.677         31        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.7it/s 17.1s
#                    all       2000       4430      0.313      0.327      0.292      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.57G       1.54      2.405      1.653         39        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.4s
#                    all       2000       4430       0.34      0.334      0.314      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.57G      1.527      2.357      1.641         45        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.0s
#                    all       2000       4430       0.33      0.368      0.321      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.57G      1.494      2.272      1.614         35        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.1s
#                    all       2000       4430       0.31      0.379      0.331      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.57G      1.484       2.22      1.602         33        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430      0.348      0.381      0.355      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.57G      1.463      2.157      1.584         44        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.8it/s 16.8s
#                    all       2000       4430      0.386      0.378       0.36      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.57G      1.453      2.124      1.572         28        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.1s
#                    all       2000       4430      0.432      0.383      0.359      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.57G      1.449      2.105      1.567         64        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.4s
#                    all       2000       4430      0.401      0.374      0.367      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.57G      1.426      2.055       1.55         23        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.3s
#                    all       2000       4430      0.379      0.398      0.368      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.57G      1.405      2.014      1.539         22        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.0s
#                    all       2000       4430      0.427      0.408      0.398      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.57G      1.407       1.97      1.535         34        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.2s
#                    all       2000       4430       0.39      0.398       0.37      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.57G      1.394      1.957      1.524         29        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.2it/s 15.1s
#                    all       2000       4430      0.491      0.407      0.413      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.57G      1.397      1.935      1.524         87        640: 100% ━━━━━━━━━━━━ 438/438 3.2it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.1s
#                    all       2000       4430      0.491      0.413      0.419      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.57G       1.38      1.894      1.509         29        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.2s
#                    all       2000       4430      0.469      0.434      0.428      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.57G      1.364      1.872      1.494         41        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.4s
#                    all       2000       4430      0.483      0.456      0.436      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.57G      1.365      1.855      1.499         45        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.8it/s 16.7s
#                    all       2000       4430      0.462      0.447      0.437      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.57G      1.357      1.824      1.485         52        640: 100% ━━━━━━━━━━━━ 438/438 3.2it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.2s
#                    all       2000       4430       0.51      0.464      0.458       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.57G      1.357      1.801      1.484         38        640: 100% ━━━━━━━━━━━━ 438/438 3.2it/s 2:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.2it/s 15.1s
#                    all       2000       4430      0.524      0.465      0.456       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.57G      1.328      1.758      1.467         30        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.2it/s 14.9s
#                    all       2000       4430      0.521      0.446      0.446      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.57G      1.331      1.768      1.462         35        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.3s
#                    all       2000       4430      0.523      0.466      0.476      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.57G      1.316       1.72      1.452         30        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.6s
#                    all       2000       4430      0.521      0.474      0.473       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.57G      1.315      1.701      1.449         31        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.6s
#                    all       2000       4430      0.538      0.448      0.458      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.57G      1.298       1.68      1.441         33        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.2it/s 15.2s
#                    all       2000       4430      0.534      0.479      0.474      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.57G      1.296      1.653      1.434         28        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.2it/s 15.2s
#                    all       2000       4430      0.511      0.474      0.468      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.57G       1.29      1.644      1.424         55        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.8s
#                    all       2000       4430      0.569      0.486        0.5      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.57G      1.275      1.611      1.415         40        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430      0.559      0.489      0.499      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.57G      1.264      1.577      1.407         33        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430      0.604      0.488      0.512      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.57G      1.255      1.566      1.404         27        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.8it/s 16.7s
#                    all       2000       4430      0.629      0.472      0.521       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.57G      1.242      1.542       1.39         21        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.5s
#                    all       2000       4430      0.561      0.499      0.509      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.57G      1.245      1.525      1.397         35        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430      0.566      0.513      0.516      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.57G      1.238      1.511      1.385         35        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.7s
#                    all       2000       4430      0.575      0.515      0.528      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.57G      1.232      1.492      1.378         33        640: 100% ━━━━━━━━━━━━ 438/438 3.2it/s 2:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.5s
#                    all       2000       4430      0.584      0.516      0.524      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.57G      1.218       1.46      1.373         37        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.8s
#                    all       2000       4430      0.624      0.504      0.538      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      2.57G      1.214      1.454      1.372         38        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.2s
#                    all       2000       4430      0.605      0.528      0.545      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.57G      1.211       1.42      1.362         31        640: 100% ━━━━━━━━━━━━ 438/438 3.0it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430      0.613      0.518       0.55      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.57G      1.197      1.421      1.354         30        640: 100% ━━━━━━━━━━━━ 438/438 3.1it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.9it/s 16.2s
#                    all       2000       4430        0.6      0.523      0.551      0.382
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.57G       1.26      1.385      1.452         28        640: 100% ━━━━━━━━━━━━ 438/438 3.3it/s 2:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.2it/s 15.1s
#                    all       2000       4430      0.649      0.507      0.552      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.57G      1.225      1.306      1.428         14        640: 100% ━━━━━━━━━━━━ 438/438 3.5it/s 2:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.3s
#                    all       2000       4430      0.649      0.525       0.56      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.57G      1.206      1.274       1.41         23        640: 100% ━━━━━━━━━━━━ 438/438 3.5it/s 2:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.7s
#                    all       2000       4430      0.627      0.534      0.561      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.57G      1.194      1.248        1.4         17        640: 100% ━━━━━━━━━━━━ 438/438 3.4it/s 2:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.6s
#                    all       2000       4430       0.62      0.543      0.566      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.57G      1.185      1.226      1.399         42        640: 100% ━━━━━━━━━━━━ 438/438 3.5it/s 2:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.2s
#                    all       2000       4430      0.653       0.53      0.568        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.57G      1.171      1.199      1.385         10        640: 100% ━━━━━━━━━━━━ 438/438 3.5it/s 2:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.4s
#                    all       2000       4430      0.671      0.532      0.572        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.57G      1.159      1.168      1.372         18        640: 100% ━━━━━━━━━━━━ 438/438 3.5it/s 2:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.1it/s 15.5s
#                    all       2000       4430      0.659      0.534      0.576      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.57G      1.149      1.153      1.362         16        640: 100% ━━━━━━━━━━━━ 438/438 3.5it/s 2:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.8s
#                    all       2000       4430      0.674      0.529      0.576      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.57G      1.142      1.149      1.356         15        640: 100% ━━━━━━━━━━━━ 438/438 3.4it/s 2:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.8s
#                    all       2000       4430      0.681      0.521      0.576      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.57G      1.136      1.128      1.349         11        640: 100% ━━━━━━━━━━━━ 438/438 3.4it/s 2:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 4.0it/s 15.6s
#                    all       2000       4430      0.675      0.532      0.581      0.409
#
# 50 epochs completed in 2.156 hours.
# Optimizer stripped from /content/runs/detect/runs/detect/cardd_damage/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/detect/runs/detect/cardd_damage/weights/best.pt, 6.2MB
#
# Validating /content/runs/detect/runs/detect/cardd_damage/weights/best.pt...
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 63/63 3.6it/s 17.7s
#                    all       2000       4430      0.676      0.533      0.581      0.409
#                  crack        283        422      0.471      0.235      0.238      0.107
#                  crash         55         55      0.591      0.578      0.622       0.39
#                   dent        750       1057      0.676      0.511      0.568      0.329
#        dislocated part        286        338      0.574      0.379      0.414      0.241
#          glass shatter        242        267      0.885      0.809      0.895      0.758
#            lamp broken        250        252      0.855      0.798      0.847      0.671
#                no part        163        178      0.595      0.416      0.491      0.286
#                    rub        167        241      0.544       0.29      0.326      0.164
#                scratch        772       1518      0.621      0.396      0.428      0.238
#              tire flat        100        102      0.948      0.922      0.978      0.911
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/runs/detect/runs/detect/cardd_damage
#
# ✅ Training complete!

# %% [markdown]
# ## Step 5 — Evaluate model

# %%
import glob
files = glob.glob('runs/**/best.pt', recursive=True)
print("Найденные модели:")
for f in files:
    print(f"  {f}")
# Out:
# Найденные модели:
#   runs/detect/runs/detect/cardd_damage/weights/best.pt

# %%
# Load the best model and run validation
best_model_path = 'runs/detect/runs/detect/cardd_damage/weights/best.pt'
model_best = YOLO(best_model_path)

# Validate on validation set
metrics = model_best.val(data=data_yaml_path)

print("\n" + "="*60)
print("📊 VALIDATION METRICS")
print("="*60)
print(f"  mAP@50:      {metrics.box.map50:.4f}")
print(f"  mAP@50-95:   {metrics.box.map:.4f}")
print(f"  Precision:   {metrics.box.mp:.4f}")
print(f"  Recall:      {metrics.box.mr:.4f}")
print("="*60)

# Per-class metrics
print("\n📋 Per-class mAP@50:")
class_names_list = list(data_config.get('names', {}).values()) if isinstance(data_config.get('names'), dict) else data_config.get('names', [])
for i, name in enumerate(class_names_list):
    if i < len(metrics.box.maps):
        print(f"  {name:20s} → mAP@50: {metrics.box.maps[i]:.4f}")
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 585.9±283.2 MB/s, size: 29.2 KB)
# val: Scanning /content/Detection-1/valid/labels.cache... 2000 images, 79 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2000/2000 349.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 125/125 6.2it/s 20.1s
#                    all       2000       4430      0.675      0.534      0.581      0.409
#                  crack        283        422      0.467      0.235       0.24      0.107
#                  crash         55         55      0.591      0.579      0.621      0.389
#                   dent        750       1057      0.675      0.516       0.57       0.33
#        dislocated part        286        338      0.562      0.379      0.413       0.24
#          glass shatter        242        267      0.881      0.805      0.895      0.758
#            lamp broken        250        252      0.846      0.798      0.846       0.67
#                no part        163        178      0.595      0.416       0.49      0.286
#                    rub        167        241      0.566      0.299      0.329      0.167
#                scratch        772       1518      0.618      0.397      0.428      0.238
#              tire flat        100        102      0.948      0.922      0.978      0.908
# Speed: 1.0ms preprocess, 3.1ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/runs/detect/val
#
# ============================================================
# 📊 VALIDATION METRICS
# ============================================================
#   mAP@50:      0.5809
#   mAP@50-95:   0.4093
#   Precision:   0.6749
#   Recall:      0.5344
# ============================================================
#
# 📋 Per-class mAP@50:
#   crack                → mAP@50: 0.1067
#   crash                → mAP@50: 0.3893
#   dent                 → mAP@50: 0.3295
#   dislocated part      → mAP@50: 0.2401
#   glass shatter        → mAP@50: 0.7579
#   lamp broken          → mAP@50: 0.6704
#   no part              → mAP@50: 0.2863
#   rub                  → mAP@50: 0.1666
#   scratch              → mAP@50: 0.2381
#   tire flat            → mAP@50: 0.9082

# %%
# Display training curves
from IPython.display import Image as IPImage, display

results_dir = 'runs/detect/cardd_damage'

# Training results plot
results_img = f'{results_dir}/results.png'
if os.path.exists(results_img):
    print("📈 Training curves:")
    display(IPImage(filename=results_img, width=900))

# Confusion matrix
cm_img = f'{results_dir}/confusion_matrix.png'
if os.path.exists(cm_img):
    print("\n📊 Confusion matrix:")
    display(IPImage(filename=cm_img, width=600))

# %% [markdown]
# ## Step 6 — Test on sample images

# %%
# Run inference on validation images
val_imgs = sorted((Path(dataset.location) / 'valid' / 'images').glob('*'))[:8]

fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle('YOLOv8 Predictions on Validation Set', fontsize=16, fontweight='bold')

for ax, img_path in zip(axes.flat, val_imgs):
    # Run prediction
    pred_results = model_best.predict(str(img_path), verbose=False, conf=0.25)

    # Get annotated image
    annotated = pred_results[0].plot()
    annotated_rgb = annotated[:, :, ::-1]  # BGR to RGB

    ax.imshow(annotated_rgb)

    # Count detections
    n_det = len(pred_results[0].boxes)
    ax.set_title(f'{img_path.name} ({n_det} damages)', fontsize=9)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 7 — Export model

# %%
import shutil

# Copy best weights to accessible location
src = 'runs/detect/runs/detect/cardd_damage/weights/best.pt'
dst = '/content/best.pt'
shutil.copy2(src, dst)

# Model info
file_size = os.path.getsize(dst) / (1024 * 1024)
print(f"✅ Model saved: {dst}")
print(f"   Size: {file_size:.1f} MB")
print(f"   mAP@50: {metrics.box.map50:.4f}")
print(f"   Classes: {class_names_list}")
print(f"\n📥 Download: click the file icon (left panel) → find best.pt → right-click → Download")
print(f"   Then put it in: Car-Damage-Assessment-AI/models/best.pt")
# Out:
# ✅ Model saved: /content/best.pt
#    Size: 5.9 MB
#    mAP@50: 0.5809
#    Classes: ['crack', 'crash', 'dent', 'dislocated part', 'glass shatter', 'lamp broken', 'no part', 'rub', 'scratch', 'tire flat']
#
# 📥 Download: click the file icon (left panel) → find best.pt → right-click → Download
#    Then put it in: Car-Damage-Assessment-AI/models/best.pt

# %%
# Also save the notebook's training config for reproducibility
training_config = {
    'model': 'yolov8n',
    'dataset': 'CarDD (Roboflow)',
    'epochs': 50,
    'imgsz': 640,
    'batch': 16,
    'mAP50': round(float(metrics.box.map50), 4),
    'mAP50_95': round(float(metrics.box.map), 4),
    'precision': round(float(metrics.box.mp), 4),
    'recall': round(float(metrics.box.mr), 4),
    'classes': class_names_list,
    'weights_file': 'best.pt',
}

import json
with open('/content/training_config.json', 'w') as f:
    json.dump(training_config, f, indent=2)

print("📋 Training config saved to /content/training_config.json")
print(json.dumps(training_config, indent=2))
# Out:
# 📋 Training config saved to /content/training_config.json
# {
#   "model": "yolov8n",
#   "dataset": "CarDD (Roboflow)",
#   "epochs": 50,
#   "imgsz": 640,
#   "batch": 16,
#   "mAP50": 0.5809,
#   "mAP50_95": 0.4093,
#   "precision": 0.6749,
#   "recall": 0.5344,
#   "classes": [
#     "crack",
#     "crash",
#     "dent",
#     "dislocated part",
#     "glass shatter",
#     "lamp broken",
#     "no part",
#     "rub",
#     "scratch",
#     "tire flat"
#   ],
#   "weights_file": "best.pt"
# }

# %%
# Optional: download via Google Drive (for large files)
# Uncomment if direct download doesn't work

# from google.colab import drive
# drive.mount('/content/drive')
# shutil.copy2('/content/best.pt', '/content/drive/MyDrive/best.pt')
# shutil.copy2('/content/training_config.json', '/content/drive/MyDrive/training_config.json')
# print("✅ Files copied to Google Drive")

# %% [markdown]
# ## ✅ Done!
#
# ### What to do next:
#
# 1. **Download** `best.pt` from the left panel (Files → right-click → Download)
# 2. **Download** `training_config.json` too
# 3. **Put them in your project:**
#    ```
#    Car-Damage-Assessment-AI/
#    ├── models/
#    │   ├── best.pt              ← trained weights
#    │   └── training_config.json ← metrics & config
#    ```
# 4. **Commit and push:**
#    ```bash
#    cd Car-Damage-Assessment-AI
#    git add models/best.pt models/training_config.json
#    git commit -m "feat: add YOLOv8 model trained on CarDD (mAP@50: X.XX)"
#    git push origin main
#    ```
#
# ### Metrics to put in README:
# After training, update the README with actual numbers from the metrics above.
